# %% [markdown]
#  # PyPRT - Dataset Collection

# %% [markdown]
# This notebook presents a way of collecting data from CGA reports. To do so, we do repeated generations of an initial shape with varying input attributes. Finally, some simple numerical processing is applied on the collected dataset.

# %%
import sys
import os

import pyprt
from pyprt.pyprt_utils import visualize_prt_results

import pandas as pd

# %%
CS_FOLDER = os.getcwd()


def asset_file(filename):
    return os.path.join(CS_FOLDER, 'data', filename)

# %% [markdown]
# #### PRT Initialization

# %%
print("\nInitializing PRT.")
pyprt.initialize_prt()

if not pyprt.is_prt_initialized():
    raise Exception("PRT is not initialized")
# Out:
# Initializing PRT.
# [PRT] [2020-02-12 10:40:44] [info] Esri Procedural Runtime
# [PRT] [2020-02-12 10:40:44] [info] Version: 2.1.5704 | Build Date: Tue 09/03/2019 06:40 PM | Build Config: PRT_BC_REL PRT_CC_OPT PRT_TC_VC141 | OS: win32 | ARCH: x86_64
# [PRT] [2020-02-12 10:40:44] [debug] prtPlugins item 0: 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib'
# [PRT] [2020-02-12 10:40:44] [error] failed to load library: error while loading library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\com.esri.prt.unreal.dll': The specified module could not be found.
#
# [PRT] [2020-02-12 10:40:44] [warning] failed to load library com.esri.prt.unreal.dll
# [PRT] [2020-02-12 10:40:44] [error] failed to load library: error while loading library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\DatasmithSDK.dll': The specified module could not be found.
#
# [PRT] [2020-02-12 10:40:44] [warning] failed to load library DatasmithSDK.dll
# [PRT] [2020-02-12 10:40:44] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\FreeImage317.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-12 10:40:44] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\LibRaw.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-12 10:40:44] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\VueExport.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-12 10:40:44] [info] Available Extensions:
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.adaptors.FileSystemAdaptor       (1.0) Resolves URIs on the file system.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.adaptors.SevenZipResolveMapProvider (2.0) Resolves URIs inside 7ZIP archives.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.adaptors.SevenZipStreamAdaptor   (2.0) Resolves URIs inside 7ZIP archives.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.adaptors.ZipFileResolveMapProvider (1.0) Resolves URIs inside ZIP archives.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.adaptors.ZipFileStreamAdaptor    (1.0) Resolves URIs inside ZIP archives.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.ACE2Decoder               (1.0) Reads ACE2 images into textures
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.ASCDecoder                (1.0) Reads Arc/Info ASCII Grid images into textures
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.AlembicEncoder            (1.0) Encodes geometry into the alembic format.
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.BINDecoder                (1.0) Reads NOAA NGS Geoid Height Grids images into textures
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.BMPDecoder                (1.0) Reads MS Windows Device Independent Bitmap images into textures
# [PRT] [2020-02-12 10:40:44] [info]     com.esri.prt.codecs.BTDecoder                 (1.0) Reads VTP .bt (Binary Terrain) 1.3 Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.ColladaDecoder            (1.0) Decodes geometry in COLLADA DAE format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.ColladaEncoder            (1.0) Encodes geometry into the Khronos COLLADA format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.DATDecoder                (1.0) Reads ZMap Plus Grid images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.DDFDecoder                (1.0) Reads SDTS Raster images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.DEMDecoder                (1.0) Reads USGS Optional ASCII DEM (and CDED) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.DxtEncoder                (1.0) Encodes images and textures into the DXT format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.E00Decoder                (1.0) Reads Arc/Info Export E00 GRID images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.FBXDecoder                (1.0) Decodes geometry in the Autodesk Filmbox (FBX) format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.FBXEncoder                (1.0) Encodes geometry into the Autodesk Filmbox (FBX) format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GENDecoder                (1.0) Reads ARC Digitized Raster Graphics images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GFFDecoder                (1.0) Reads Ground-based SAR Applications Testbed File Format (.gff) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GIFDecoder                (1.0) Reads Graphics Interchange Format (.gif) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GLTFDecoder               (1.0) Decodes geometry from the glTF format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GLTFEncoder               (1.0) Encodes geometry into the Khronos Group glTF 2.0 format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GLTFResolveMapProvider    (1.0) Resolves URIs for GLTF embedded data.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GRBDecoder                (1.0) Reads GRIdded Binary (.grb) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GRCDecoder                (1.0) Reads Northwood Classified Grid Format .grc/.tab images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GRDDecoder                (1.0) Reads Golden Software ASCII Grid (.grd) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GSBDecoder                (1.0) Reads NTv2 Datum Grid Shift images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.GTXDecoder                (1.0) Reads NOAA Vertical Datum .GTX images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.HDRDecoder                (1.0) Reads Snow Data Assimilation System images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.HF2Decoder                (1.0) Reads HF2/HFZ heightfield raster images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.HGTDecoder                (1.0) Reads SRTMHGT File Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.I3SEncoder                (1.0) Creates Scene Layer Packages that can be shared on ArcGIS Online/Portal.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.IMGDecoder                (1.0) Reads Erdas Imagine Images (.img) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.JPGDecoder                (1.0) Reads JPEG JFIF images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.JPGEncoder                (1.0) Encodes images and textures into the JPEG format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.LCPDecoder                (1.0) Reads FARSITE v.4 Landscape File (.lcp) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.LercEncoder               (1.0) Encodes images and textures into the LERC format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.MEMDecoder                (1.0) Reads Japanese DEM (.mem) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.MPRDecoder                (1.0) Reads ILWIS Raster Map images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.MTLDecoder                (1.0) Reads materials in Wavefront MTL format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.MTLEncoder                (1.0) Converts materials into Wavefront MTL format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.N1Decoder                 (1.0) Reads Envisat Image Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.NTFDecoder                (1.0) Reads National Imagery Transmission Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.OBJDecoder                (1.0) Decodes geometry from the Wavefront OBJ format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.OBJEncoder                (1.0) Encodes geometry into the Wavefront OBJ format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.PIXDecoder                (1.0) Reads PCIDSK Database File images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.PNGDecoder                (1.0) Reads Portable Network Graphics images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.PNGEncoder                (1.0) Encodes images and textures into the PNG format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.PNMDecoder                (1.0) Reads Portable Pixmap Format (netpbm) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.RAWEncoder                (1.0) Stores the uncompressed image as data blob.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.RDADecoder                (1.0) Reads R Object Data Store images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.RSTDecoder                (1.0) Reads Idrisi Raster A.1 images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.RSWDecoder                (1.0) Reads Raster Matrix Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.RenderManEncoder          (1.0) Encodes geometry to Pixar RenderMan.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.SDATDecoder               (1.0) Reads SAGA GIS Binary Grid (.sdat) images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.ShapeBufferDecoder        (1.0) Reads Esri shape buffer geometry (only extended MultiPatch buffer).
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.ShapeBufferEncoder        (1.0) Encodes geometry into the esri shape buffer format (revision 2012-02-17).
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.TIFDecoder                (1.0) Reads GeoTIFF images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.TIFFEncoder               (1.0) Encodes images and textures into the TIFF format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.VOBEncoder                (1.0) Encodes geometry into the E-On Software Vue VOB format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.VRTDecoder                (1.0) Reads Virtual Raster images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.WebSceneEncoder           (1.0) Exports a scene into the Esri WebScene format.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.WebSceneObjectEncoder     (1.0) Encodes geometry into Esri WebScene Objects.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.XPMDecoder                (1.0) Reads X11 PixMap Format images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.codecs.XYZDecoder                (1.0) Reads ASCII Gridded XYZ images into textures
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.AttributeEvalEncoder        (1.0) Sets the values of (evaluated) shape attributes.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.CGAErrorEncoder             (1.0) Handles errors encountered during CGA execution.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.CGAPrintEncoder             (1.0) Handles the output of the CGA print statement.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.CGAReportEncoder            (1.0) Handles report output generated by CGA.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.CGBDecoder                  (1.0) CGB Byte Stream Reader
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.MemoryAdaptor               (1.0) Reads data in memory into a stream for decoding.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.OcclusionEncoder            (1.0) Encodes a shape tree into the OcclusionSet for inter-occlusion.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.RawTextureDecoder           (1.0) Reads raw (uncompressed) images into textures.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.prt.core.TextDecoder                 (1.0) Decodes text (ASCII, UTF-8, UTF-16) to a UTF-16 string.
# [PRT] [2020-02-12 10:40:45] [info]     com.esri.pyprt.PyEncoder                      (1.0) Encodes geometry and CGA report for Python.

# %%
v = [0, 0, 0,  0, 0, 20,  10, 0, 10,  10, 0, 0]
initial_shape1 = pyprt.InitialShape(v)

rpk = asset_file("extrusion_rule.rpk")
attrs = {'ruleFile': 'bin/extrusion_rule.cgb',
         'startRule': 'Default$Footprint'}

mod = pyprt.ModelGenerator([initial_shape1])
generated_model = mod.generate_model(
    [attrs], rpk, 'com.esri.pyprt.PyEncoder', {})

visualize_prt_results(generated_model)
# Out:
# [PRT] [2020-02-12 10:40:56] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\extrusion_rule.rpk
#
# [PRT] [2020-02-12 10:40:56] [debug] resolve map = <ResolveMap>
# 	<attribute key="/test-prt4cmd/rules/extrusion_rule.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/rules/extrusion_rule.cga" type="str"/>
# 	<attribute key="bin/extrusion_rule.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/bin/extrusion_rule.cgb" type="str"/>
# 	<attribute key="rules/extrusion_rule.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/rules/extrusion_rule.cga" type="str"/>
# </ResolveMap>
#
# [PRT] [2020-02-12 10:40:56] [warning] CGB file contains warning 'Potentially unsupported CGAC version 1.14 : newer than current (1.13)'
#
# Number of generated geometries (= nber of initial shapes):
# 1
#
# Initial Shape Index: 0
#
# Size of the matrix containing the model vertices (with possible duplicates): (8, 3)
# Size of the matrix containing the model faces: 6
#
# Report of the generated model:
# {'Bool value_sum': True, 'Bool value_avg': True, 'Bool value_min': True, 'Bool value_max': True, 'Bool value_n': 1.0, 'Building Height.0_n': 1.0, 'Id_n': 1.0, 'Max Height.0_n': 1.0, 'Min Height.0_n': 1.0, 'Parcel Area.0_n': 1.0, 'Text_n': 1.0, 'Value_n': 1.0, 'Building Height.0_sum': 11.216289589885635, 'Building Height.0_avg': 11.216289589885635, 'Id_sum': 0.0, 'Id_avg': 0.0, 'Max Height.0_sum': 30.0, 'Max Height.0_avg': 30.0, 'Min Height.0_sum': 10.0, 'Min Height.0_avg': 10.0, 'Parcel Area.0_sum': 149.99999304605885, 'Parcel Area.0_avg': 149.99999304605885, 'Value_sum': 1.0, 'Value_avg': 1.0, 'Building Height.0_min': 11.216289589885635, 'Building Height.0_max': 11.216289589885635, 'Id_min': 0.0, 'Id_max': 0.0, 'Max Height.0_min': 30.0, 'Max Height.0_max': 30.0, 'Min Height.0_min': 10.0, 'Min Height.0_max': 10.0, 'Parcel Area.0_min': 149.99999304605885, 'Parcel Area.0_max': 149.99999304605885, 'Value_min': 1.0, 'Value_max': 1.0, 'Text_sum': 'salut', 'Text_avg': 'salut', 'Text_min': 'salut', 'Text_max': 'salut'}

# %% [markdown]
# #### RPK to gather values in report

# %%
def get_sum_report(model):
    sum_rep = {}
    all_rep = model.get_report()
    for it in all_rep:
        if "_sum" in it:
            sum_rep[it] = all_rep[it]
    return sum_rep

# %%
initial_shape2 = pyprt.InitialShape(
    [0, 0, 0,  0, 0, 10,  10, 0, 10,  10, 0, 0])
initial_shape3 = pyprt.InitialShape(
    [0, 0, 0,  0, 0, 30,  10, 0, 10,  10, 0, 0])

# %%
reports = []
model_to_generate = pyprt.ModelGenerator(
    [initial_shape1, initial_shape2, initial_shape3])
model_test = model_to_generate.generate_model(
    [attrs], rpk, 'com.esri.pyprt.PyEncoder', {'emitGeometry': False})

for val in range(0, 10):
    attrs['minBuildingHeight'] = float(val)
    models = model_to_generate.generate_model([attrs])

    for model in models:
        if model:
            reports.append(get_sum_report(model))
# Out:
# [PRT] [2020-02-12 10:41:02] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\extrusion_rule.rpk
#
# [PRT] [2020-02-12 10:41:02] [debug] resolve map = <ResolveMap>
# 	<attribute key="/test-prt4cmd/rules/extrusion_rule.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/rules/extrusion_rule.cga" type="str"/>
# 	<attribute key="bin/extrusion_rule.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/bin/extrusion_rule.cgb" type="str"/>
# 	<attribute key="rules/extrusion_rule.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cextrusion_rule.rpk!/rules/extrusion_rule.cga" type="str"/>
# </ResolveMap>
#
# [PRT] [2020-02-12 10:41:02] [warning] CGB file contains warning 'Potentially unsupported CGAC version 1.14 : newer than current (1.13)'

# %% [markdown]
# #### Transform report in pandas dataframe in order to process the dataset before training any ML/DL model on it:

# %%
reports_df = pd.DataFrame(reports)
reports_df
# Out:
#     Bool value_sum  Building Height.0_sum  Id_sum  Max Height.0_sum  \
# 0             True               1.824434     0.0              30.0
# 1             True               1.824434     0.0              30.0
# 2             True               1.824434     0.0              30.0
# 3             True               2.763620     0.0              30.0
# 4             True               2.763620     0.0              30.0
# 5             True               2.763620     0.0              30.0
# 6             True               3.702806     0.0              30.0
# 7             True               3.702806     0.0              30.0
# 8             True               3.702806     0.0              30.0
# 9             True               4.641991     0.0              30.0
# 10            True               4.641991     0.0              30.0
# 11            True               4.641991     0.0              30.0
# 12            True               5.581176     0.0              30.0
# 13            True               5.581176     0.0              30.0
# 14            True               5.581176     0.0              30.0
# 15            True               6.520362     0.0              30.0
# 16            True               6.520362     0.0              30.0
# 17            True               6.520362     0.0              30.0
# 18            True               7.459548     0.0              30.0
# 19            True               7.459548     0.0              30.0
# 20            True               7.459548     0.0              30.0
# 21            True               8.398733     0.0              30.0
# 22            True               8.398733     0.0              30.0
# 23            True               8.398733     0.0              30.0
# 24            True               9.337918     0.0              30.0
# 25            True               9.337918     0.0              30.0
# 26            True               9.337918     0.0              30.0
# 27            True              10.277104     0.0              30.0
# 28            True              10.277104     0.0              30.0
# 29            True              10.277104     0.0              30.0
#
#     Min Height.0_sum  Parcel Area.0_sum  Value_sum Text_sum
# 0                0.0         149.999993        1.0    salut
# 1                0.0          99.999998        1.0    salut
# 2                0.0         199.999993        1.0    salut
# 3                1.0         149.999993        1.0    salut
# 4                1.0          99.999998        1.0    salut
# 5                1.0         199.999993        1.0    salut
# 6                2.0         149.999993        1.0    salut
# 7                2.0          99.999998        1.0    salut
# 8                2.0         199.999993        1.0    salut
# 9                3.0         149.999993        1.0    salut
# 10               3.0          99.999998        1.0    salut
# 11               3.0         199.999993        1.0    salut
# 12               4.0         149.999993        1.0    salut
# 13               4.0          99.999998        1.0    salut
# 14               4.0         199.999993        1.0    salut
# 15               5.0         149.999993        1.0    salut
# 16               5.0          99.999998        1.0    salut
# 17               5.0         199.999993        1.0    salut
# 18               6.0         149.999993        1.0    salut
# 19               6.0          99.999998        1.0    salut
# 20               6.0         199.999993        1.0    salut
# 21               7.0         149.999993        1.0    salut
# 22               7.0          99.999998        1.0    salut
# 23               7.0         199.999993        1.0    salut
# 24               8.0         149.999993        1.0    salut
# 25               8.0          99.999998        1.0    salut
# 26               8.0         199.999993        1.0    salut
# 27               9.0         149.999993        1.0    salut
# 28               9.0          99.999998        1.0    salut
# 29               9.0         199.999993        1.0    salut

# %%
dataset_uniqueRows = reports_df.drop_duplicates()

# %%
dataset_uniqueRows
# Out:
#     Bool value_sum  Building Height.0_sum  Id_sum  Max Height.0_sum  \
# 0             True               1.824434     0.0              30.0
# 1             True               1.824434     0.0              30.0
# 2             True               1.824434     0.0              30.0
# 3             True               2.763620     0.0              30.0
# 4             True               2.763620     0.0              30.0
# 5             True               2.763620     0.0              30.0
# 6             True               3.702806     0.0              30.0
# 7             True               3.702806     0.0              30.0
# 8             True               3.702806     0.0              30.0
# 9             True               4.641991     0.0              30.0
# 10            True               4.641991     0.0              30.0
# 11            True               4.641991     0.0              30.0
# 12            True               5.581176     0.0              30.0
# 13            True               5.581176     0.0              30.0
# 14            True               5.581176     0.0              30.0
# 15            True               6.520362     0.0              30.0
# 16            True               6.520362     0.0              30.0
# 17            True               6.520362     0.0              30.0
# 18            True               7.459548     0.0              30.0
# 19            True               7.459548     0.0              30.0
# 20            True               7.459548     0.0              30.0
# 21            True               8.398733     0.0              30.0
# 22            True               8.398733     0.0              30.0
# 23            True               8.398733     0.0              30.0
# 24            True               9.337918     0.0              30.0
# 25            True               9.337918     0.0              30.0
# 26            True               9.337918     0.0              30.0
# 27            True              10.277104     0.0              30.0
# 28            True              10.277104     0.0              30.0
# 29            True              10.277104     0.0              30.0
#
#     Min Height.0_sum  Parcel Area.0_sum  Value_sum Text_sum
# 0                0.0         149.999993        1.0    salut
# 1                0.0          99.999998        1.0    salut
# 2                0.0         199.999993        1.0    salut
# 3                1.0         149.999993        1.0    salut
# 4                1.0          99.999998        1.0    salut
# 5                1.0         199.999993        1.0    salut
# 6                2.0         149.999993        1.0    salut
# 7                2.0          99.999998        1.0    salut
# 8                2.0         199.999993        1.0    salut
# 9                3.0         149.999993        1.0    salut
# 10               3.0          99.999998        1.0    salut
# 11               3.0         199.999993        1.0    salut
# 12               4.0         149.999993        1.0    salut
# 13               4.0          99.999998        1.0    salut
# 14               4.0         199.999993        1.0    salut
# 15               5.0         149.999993        1.0    salut
# 16               5.0          99.999998        1.0    salut
# 17               5.0         199.999993        1.0    salut
# 18               6.0         149.999993        1.0    salut
# 19               6.0          99.999998        1.0    salut
# 20               6.0         199.999993        1.0    salut
# 21               7.0         149.999993        1.0    salut
# 22               7.0          99.999998        1.0    salut
# 23               7.0         199.999993        1.0    salut
# 24               8.0         149.999993        1.0    salut
# 25               8.0          99.999998        1.0    salut
# 26               8.0         199.999993        1.0    salut
# 27               9.0         149.999993        1.0    salut
# 28               9.0          99.999998        1.0    salut
# 29               9.0         199.999993        1.0    salut

# %% [markdown]
# The next steps in a ML/DL application would be to split the dataset into a training and a testing set. Finally, the idea would be to train an algorithm on the training set.

# %%
print("\nShutdown PRT.")
pyprt.shutdown_prt()
# Out:
# Shutdown PRT.
