# %% [markdown]
# # PyPRT - Building Modeling Optimization

# %% [markdown]
# In this notebook, we are using a CGA rule that allows us to generate modern and sustainable buildings. The architecture of these buildings is focused on the green aspect of the building. Therefore, in addition to be modern and esthetical, the generated building answers also to the actual requirements of the city which are to encourage the integration of greenery on the buildings.

# %% [markdown]
# ![bosco_verticale.jpg](attachment:bosco_verticale.jpg)

# %% [markdown]
# Bosco Verticale in Milan

# %% [markdown]
# #### Imports

# %%
import sys
import os
from scipy import optimize
import numpy as np
from PyGEL3D import gel, js

# %%
import pyprt
pyprt.initialize_prt()

if(not pyprt.is_prt_initialized()):
    raise Exception("PRT is not initialized")
# Out:
# [PRT] [2020-02-13 09:48:14] [info] Esri Procedural Runtime
# [PRT] [2020-02-13 09:48:14] [info] Version: 2.1.5704 | Build Date: Tue 09/03/2019 06:40 PM | Build Config: PRT_BC_REL PRT_CC_OPT PRT_TC_VC141 | OS: win32 | ARCH: x86_64
# [PRT] [2020-02-13 09:48:14] [debug] prtPlugins item 0: 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib'
# [PRT] [2020-02-13 09:48:15] [error] failed to load library: error while loading library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\com.esri.prt.unreal.dll': The specified module could not be found.
#
# [PRT] [2020-02-13 09:48:15] [warning] failed to load library com.esri.prt.unreal.dll
# [PRT] [2020-02-13 09:48:15] [error] failed to load library: error while loading library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\DatasmithSDK.dll': The specified module could not be found.
#
# [PRT] [2020-02-13 09:48:15] [warning] failed to load library DatasmithSDK.dll
# [PRT] [2020-02-13 09:48:15] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\FreeImage317.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-13 09:48:15] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\LibRaw.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-13 09:48:15] [debug] library 'c:\users\cami9495\documents\esri-cityengine-sdk-master\examples\py4prt\pyprt\pyprt\lib\VueExport.dll' is not a compatible extension (reason: 'error while loading function 'getVersionMajor': The specified procedure could not be found.
# ')
# [PRT] [2020-02-13 09:48:15] [info] Available Extensions:
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.adaptors.FileSystemAdaptor       (1.0) Resolves URIs on the file system.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.adaptors.SevenZipResolveMapProvider (2.0) Resolves URIs inside 7ZIP archives.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.adaptors.SevenZipStreamAdaptor   (2.0) Resolves URIs inside 7ZIP archives.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.adaptors.ZipFileResolveMapProvider (1.0) Resolves URIs inside ZIP archives.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.adaptors.ZipFileStreamAdaptor    (1.0) Resolves URIs inside ZIP archives.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ACE2Decoder               (1.0) Reads ACE2 images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ASCDecoder                (1.0) Reads Arc/Info ASCII Grid images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.AlembicEncoder            (1.0) Encodes geometry into the alembic format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.BINDecoder                (1.0) Reads NOAA NGS Geoid Height Grids images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.BMPDecoder                (1.0) Reads MS Windows Device Independent Bitmap images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.BTDecoder                 (1.0) Reads VTP .bt (Binary Terrain) 1.3 Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ColladaDecoder            (1.0) Decodes geometry in COLLADA DAE format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ColladaEncoder            (1.0) Encodes geometry into the Khronos COLLADA format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.DATDecoder                (1.0) Reads ZMap Plus Grid images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.DDFDecoder                (1.0) Reads SDTS Raster images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.DEMDecoder                (1.0) Reads USGS Optional ASCII DEM (and CDED) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.DxtEncoder                (1.0) Encodes images and textures into the DXT format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.E00Decoder                (1.0) Reads Arc/Info Export E00 GRID images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.FBXDecoder                (1.0) Decodes geometry in the Autodesk Filmbox (FBX) format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.FBXEncoder                (1.0) Encodes geometry into the Autodesk Filmbox (FBX) format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GENDecoder                (1.0) Reads ARC Digitized Raster Graphics images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GFFDecoder                (1.0) Reads Ground-based SAR Applications Testbed File Format (.gff) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GIFDecoder                (1.0) Reads Graphics Interchange Format (.gif) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GLTFDecoder               (1.0) Decodes geometry from the glTF format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GLTFEncoder               (1.0) Encodes geometry into the Khronos Group glTF 2.0 format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GLTFResolveMapProvider    (1.0) Resolves URIs for GLTF embedded data.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GRBDecoder                (1.0) Reads GRIdded Binary (.grb) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GRCDecoder                (1.0) Reads Northwood Classified Grid Format .grc/.tab images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GRDDecoder                (1.0) Reads Golden Software ASCII Grid (.grd) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GSBDecoder                (1.0) Reads NTv2 Datum Grid Shift images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.GTXDecoder                (1.0) Reads NOAA Vertical Datum .GTX images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.HDRDecoder                (1.0) Reads Snow Data Assimilation System images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.HF2Decoder                (1.0) Reads HF2/HFZ heightfield raster images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.HGTDecoder                (1.0) Reads SRTMHGT File Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.I3SEncoder                (1.0) Creates Scene Layer Packages that can be shared on ArcGIS Online/Portal.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.IMGDecoder                (1.0) Reads Erdas Imagine Images (.img) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.JPGDecoder                (1.0) Reads JPEG JFIF images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.JPGEncoder                (1.0) Encodes images and textures into the JPEG format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.LCPDecoder                (1.0) Reads FARSITE v.4 Landscape File (.lcp) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.LercEncoder               (1.0) Encodes images and textures into the LERC format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.MEMDecoder                (1.0) Reads Japanese DEM (.mem) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.MPRDecoder                (1.0) Reads ILWIS Raster Map images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.MTLDecoder                (1.0) Reads materials in Wavefront MTL format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.MTLEncoder                (1.0) Converts materials into Wavefront MTL format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.N1Decoder                 (1.0) Reads Envisat Image Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.NTFDecoder                (1.0) Reads National Imagery Transmission Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.OBJDecoder                (1.0) Decodes geometry from the Wavefront OBJ format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.OBJEncoder                (1.0) Encodes geometry into the Wavefront OBJ format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.PIXDecoder                (1.0) Reads PCIDSK Database File images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.PNGDecoder                (1.0) Reads Portable Network Graphics images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.PNGEncoder                (1.0) Encodes images and textures into the PNG format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.PNMDecoder                (1.0) Reads Portable Pixmap Format (netpbm) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.RAWEncoder                (1.0) Stores the uncompressed image as data blob.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.RDADecoder                (1.0) Reads R Object Data Store images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.RSTDecoder                (1.0) Reads Idrisi Raster A.1 images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.RSWDecoder                (1.0) Reads Raster Matrix Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.RenderManEncoder          (1.0) Encodes geometry to Pixar RenderMan.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.SDATDecoder               (1.0) Reads SAGA GIS Binary Grid (.sdat) images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ShapeBufferDecoder        (1.0) Reads Esri shape buffer geometry (only extended MultiPatch buffer).
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.ShapeBufferEncoder        (1.0) Encodes geometry into the esri shape buffer format (revision 2012-02-17).
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.TIFDecoder                (1.0) Reads GeoTIFF images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.TIFFEncoder               (1.0) Encodes images and textures into the TIFF format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.VOBEncoder                (1.0) Encodes geometry into the E-On Software Vue VOB format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.VRTDecoder                (1.0) Reads Virtual Raster images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.WebSceneEncoder           (1.0) Exports a scene into the Esri WebScene format.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.WebSceneObjectEncoder     (1.0) Encodes geometry into Esri WebScene Objects.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.XPMDecoder                (1.0) Reads X11 PixMap Format images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.codecs.XYZDecoder                (1.0) Reads ASCII Gridded XYZ images into textures
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.AttributeEvalEncoder        (1.0) Sets the values of (evaluated) shape attributes.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.CGAErrorEncoder             (1.0) Handles errors encountered during CGA execution.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.CGAPrintEncoder             (1.0) Handles the output of the CGA print statement.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.CGAReportEncoder            (1.0) Handles report output generated by CGA.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.CGBDecoder                  (1.0) CGB Byte Stream Reader
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.MemoryAdaptor               (1.0) Reads data in memory into a stream for decoding.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.OcclusionEncoder            (1.0) Encodes a shape tree into the OcclusionSet for inter-occlusion.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.RawTextureDecoder           (1.0) Reads raw (uncompressed) images into textures.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.prt.core.TextDecoder                 (1.0) Decodes text (ASCII, UTF-8, UTF-16) to a UTF-16 string.
# [PRT] [2020-02-13 09:48:15] [info]     com.esri.pyprt.PyEncoder                      (1.0) Encodes geometry and CGA report for Python.

# %% [markdown]
# ## Optimization Problem Definition

# %% [markdown]
# Given the architectural design of this building (defined by the CGA rule) and the parcel, which value of the **lot coverage**, **tier height** and **building shape** should we choose in order to maximize the building green potential (green area).

# %% [markdown]
# ![green_building_parameters.png](attachment:green_building_parameters.PNG)

# %% [markdown]
# In this example, only the previously mentioned variables were taken into account for simplicity purposes. For instance, the building parcel geographical orientation is not known. Therefore, the sun direction could not be derived. The well-being of the plants and greenery is thus not considered.

# %% [markdown]
# ### Given: building architecture (CGA Rule Package) and parcel to redevelop

# %%
rpk_green = os.path.join(os.getcwd(), 'data', 'envelope0110.rpk')
attrs_green = {'ruleFile': 'rules/typology/envelope0110.cgb',
               'startRule': 'Default$Lot', 'report_but_not_display_green': True}
shape_geo = pyprt.InitialShape(os.path.join(
    os.getcwd(), 'data', 'building_parcel.obj'))

# %% [markdown]
# ### Greenery Optimization

# %% [markdown]
# Step 1 : optimize the total green area reported (including the balconies trees). This will be optimized taking into account several parameters:
# - the shape of the building (1 = orthogonal, 2 = L shape, 3 = U shape, 4 = O shapes)
# - the lot coverage
# - the height of the first tier

# %% [markdown]
# #### Optimization Variables

# %%
goal_str_green = 'Greenery Area' + '_sum'

input_attr_green = ['lot_coverage_parameter',
                    'height_first_tier', 'shape_of_building']
x0_green = [float(50), float(9), float(round(2))]

# %%
attrs_green = {'ruleFile': 'rules/typology/envelope0110.cgb',
               'startRule': 'Default$Lot', 'report_but_not_display_green': True}

m = pyprt.ModelGenerator([shape_geo])
model = m.generate_model([attrs_green], rpk_green,
                         'com.esri.pyprt.PyEncoder', {'emitGeometry': False})
# Out:
# [PRT] [2020-02-13 09:49:09] [debug] trying to read initial shape geometry from file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cbuilding_parcel.obj
#
# [PRT] [2020-02-13 09:49:09] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\envelope0110.rpk
#
# [PRT] [2020-02-13 09:49:09] [debug] resolve map = <ResolveMap>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Distributor.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Distributor.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Loader.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Loader.cga" type="str"/>
# 	<attribute key="assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cgb" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# </ResolveMap>

# %%
def fct_green(x):

    attrs_green[input_attr_green[0]] = x[0]
    attrs_green[input_attr_green[1]] = x[1]
    attrs_green[input_attr_green[2]] = float(round(x[2]))
    generated_mod_green = m.generate_model([attrs_green])

    if generated_mod_green:
        rep_green = generated_mod_green[0].get_report()
        return -rep_green[goal_str_green]
    else:
        print('Error in optimization process.')

# %% [markdown]
# #### Variables boundaries

# %%
bounds_green = [(0, 100), (8, 13), (1, 4)]

# %% [markdown]
# The SciPy optimization library is extensively used within Python community. However, **any** optimization algorithm works with PyPRT. In this notebook, the optimization problem to solve is complex and highly non linear. The differential evolution algorithm from SciPy is particularly suited to our problem because it is stochastic and, thus, does not need any gradient computation to find the minimum. The choice of optimization algorithm depends on the problem and, in our case, in the CGA rule.

# %%
res_green = optimize.differential_evolution(
    fct_green, bounds_green, tol=0.15, seed=666)
res_green
# Out:
#      fun: -4065.8768645564187
#  message: 'Optimization terminated successfully.'
#     nfev: 184
#      nit: 3
#  success: True
#        x: array([34.99030757, 11.35376576,  3.69885958])

# %% [markdown]
# #### Results Visualization

# %%
export_file_name = 'ex7_optimalmodel1'
enc_options = {'baseName': export_file_name,
               'outputPath': os.path.join(os.getcwd(), 'ex7_output')}
os.makedirs(enc_options['outputPath'], exist_ok=True)

attrs_green[input_attr_green[0]] = res_green.x[0]
attrs_green[input_attr_green[1]] = res_green.x[1]
attrs_green[input_attr_green[2]] = float(round(res_green.x[2]))
green_model = m.generate_model(
    [attrs_green], rpk_green, 'com.esri.prt.codecs.OBJEncoder', enc_options)
# Out:
# [PRT] [2020-02-13 09:55:16] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\envelope0110.rpk
#
# [PRT] [2020-02-13 09:55:16] [debug] resolve map = <ResolveMap>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Distributor.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Distributor.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Loader.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Loader.cga" type="str"/>
# 	<attribute key="assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cgb" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# </ResolveMap>
#
# [PRT] [2020-02-13 09:55:16] [debug] got outputPath = "C:\\Users\\cami9495\\Documents\\esri-cityengine-sdk-master\\examples\\py4prt\\examples\\ex7_output"

# %%
image = gel.obj_load(os.path.join(
    enc_options['outputPath'], export_file_name+'.obj'))
js.display(image, smooth=False)
# Out:
# FigureWidget({
#     'data': [{'color': '#dddddd',
#               'flatshading': True,
#               'i': array([…

# %% [markdown]
# The textures are not shown here. Open the OBJ file with another app to see the colorful model. Depending on your needs, a GLTF file could be useful. In this case, export the 3D generated model using the "com.esri.prt.codecs.GLTFEncoder".

# %% [markdown]
# ## Multi-Objectives Optimization

# %% [markdown]
# Step 2 : optimize the green area reported including the balconies trees AND the floor area in order to avoid thin walls. We will keep O-shape building. This will be optimized taking into account several parameters:
#
# - the lot coverage
# - the height of the first tier

# %% [markdown]
# #### Optimization Variables

# %%
goal_str_green = 'Greenery Area' + '_sum'
goal_str_floor = 'Floor area' + '_sum'
# this allows having similar range between the green area and the floor area
floor_weight = 0.07

input_attr_green = ['lot_coverage_parameter', 'height_first_tier']
x0_green = [float(50), float(9)]

# %%
attrs_green = {'ruleFile': 'rules/typology/envelope0110.cgb', 'startRule': 'Default$Lot',
               'report_but_not_display_green': True, 'shape_of_building': 4.0}

model2 = m.generate_model([attrs_green], rpk_green,
                          'com.esri.pyprt.PyEncoder', {'emitGeometry': False})
# Out:
# [PRT] [2020-02-13 10:01:19] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\envelope0110.rpk
#
# [PRT] [2020-02-13 10:01:19] [debug] resolve map = <ResolveMap>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Distributor.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Distributor.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Loader.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Loader.cga" type="str"/>
# 	<attribute key="assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cgb" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# </ResolveMap>

# %%
def fct_green(x):

    attrs_green[input_attr_green[0]] = x[0]
    attrs_green[input_attr_green[1]] = x[1]
    generated_mod_green = m.generate_model([attrs_green])

    if generated_mod_green:
        rep_green = generated_mod_green[0].get_report()
        return -(rep_green[goal_str_green]+floor_weight*rep_green[goal_str_floor])
    else:
        print('Error in optimization process.')

# %%
bounds_green = [(0, 100), (8, 13)]

# %%
res_green = optimize.differential_evolution(
    fct_green, bounds_green, tol=0.1, seed=666)
res_green
# Out:
#      fun: -4702.021447917708
#  message: 'Optimization terminated successfully.'
#     nfev: 93
#      nit: 2
#  success: True
#        x: array([60.56927098, 12.64878533])

# %% [markdown]
# #### Results Visualization

# %%
export_file_name = 'ex7_optimalmodel2'
enc_options['baseName'] = export_file_name

attrs_green[input_attr_green[0]] = res_green.x[0]
attrs_green[input_attr_green[1]] = res_green.x[1]
green_model = m.generate_model(
    [attrs_green], rpk_green, 'com.esri.prt.codecs.OBJEncoder', enc_options)
# Out:
# [PRT] [2020-02-13 10:04:55] [info] using rule package C:\Users\cami9495\Documents\esri-cityengine-sdk-master\examples\py4prt\examples\data\envelope0110.rpk
#
# [PRT] [2020-02-13 10:04:55] [debug] resolve map = <ResolveMap>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Distributor.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Distributor.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="assets/lawn2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/lawn2.jpg" type="str"/>
# 	<attribute key="assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/1.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/1.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cga" type="str"/>
# 	<attribute key="assets/concrete.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/concrete.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/Bench/ooMaterial2.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/ooMaterial2.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/3.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/3.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/brick_wall.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/brick_wall.jpg" type="str"/>
# 	<attribute key="/ESRI.lib/rules/Plants/Plant_Loader.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/.ws/ESRI.lib/rules/Plants/Plant_Loader.cga" type="str"/>
# 	<attribute key="assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="rules/typology/envelope0110.cgb" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/envelope0110.cgb" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/4.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/4.PNG" type="str"/>
# 	<attribute key="assets/unified_landscape/plan4.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/6.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/6.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/10.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/10.PNG" type="str"/>
# 	<attribute key="assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wall_plaster.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wall_plaster.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan1.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan1.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/9.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/9.PNG" type="str"/>
# 	<attribute key="assets/vertical_greenery/7.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/7.PNG" type="str"/>
# 	<attribute key="rules/typology/landscape.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/landscape.cga" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/volume0110.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/volume0110.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/vertical_greenery/8.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/8.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/bench.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/bench.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/ground_floor_plan.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/ground_floor_plan.cga" type="str"/>
# 	<attribute key="rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="assets/glass_door.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/glass_door.obj" type="str"/>
# 	<attribute key="assets/vertical_greenery/2.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/2.PNG" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="assets/unified_landscape/plan3.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan3.mtl" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan2.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan2.obj" type="str"/>
# 	<attribute key="/green_optimization_3/assets/unified_landscape/plan4.obj" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/unified_landscape/plan4.obj" type="str"/>
# 	<attribute key="/green_optimization_3/rules/typology/facade.cga" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/rules/typology/facade.cga" type="str"/>
# 	<attribute key="/green_optimization_3/assets/paving_b.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/paving_b.jpg" type="str"/>
# 	<attribute key="assets/Bench/_1.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench/_1.jpg" type="str"/>
# 	<attribute key="assets/Bench.mtl" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/Bench.mtl" type="str"/>
# 	<attribute key="assets/vertical_greenery/5.PNG" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/vertical_greenery/5.PNG" type="str"/>
# 	<attribute key="assets/wood.jpg" value="rpk:file:/C:%5CUsers%5Ccami9495%5CDocuments%5Cesri-cityengine-sdk-master%5Cexamples%5Cpy4prt%5Cexamples%5Cdata%5Cenvelope0110.rpk!/assets/wood.jpg" type="str"/>
# </ResolveMap>
#
# [PRT] [2020-02-13 10:04:55] [debug] got outputPath = "C:\\Users\\cami9495\\Documents\\esri-cityengine-sdk-master\\examples\\py4prt\\examples\\ex7_output"

# %%
image = gel.obj_load(os.path.join(
    enc_options['outputPath'], export_file_name+'_0.obj'))
js.display(image, smooth=False)
# Out:
# FigureWidget({
#     'data': [{'color': '#dddddd',
#               'flatshading': True,
#               'i': array([…

# %%
pyprt.shutdown_prt()
